# %% [markdown]
# # TSM Assignment

# %% [markdown]
# Overleaf: https://www.overleaf.com/5382115821nbvwqrncqwrc

# %% [markdown]
# #### Libraries

# %%
pip install pandas

# %%
pip install scipy

# %%
pip install matplotlib

# %%
pip install -U numpy scipy scikit-learn

# %%
import pandas as pd
import numpy as np
import scipy
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
import pickle

# %% [markdown]
# #### Data

# %%
# Read data (Skipping lines without data)
data_real = pd.read_csv("data_real.csv", sep=",", skiprows=18) # indlæser fil
data_nom = pd.read_csv("data_nom.csv", sep=",", skiprows=9) # indlæser fil

# Select maturities 2, 3, 5, 7, 10 years and end_of_month dates
data_real = data_real.query("Date >= '2005-01-01' and Date <= '2023-03-31'").set_index('Date')
data_real = data_real[['TIPSY02', 'TIPSY03', 'TIPSY05', 'TIPSY07', 'TIPSY10']]

data_nom = data_nom.query("Date >= '2005-01-01' and Date <= '2023-03-31'").set_index('Date')
data_nom = data_nom[['SVENY02', 'SVENY03', 'SVENY05', 'SVENY07', 'SVENY10']]

data_nom.index = pd.to_datetime(data_nom.index) # omskriver til dato
data_nom = data_nom.resample('M').last() # de seneste måneder
data_nom.index = data_nom.index.strftime('%Y-%b') # dataformat

data_real.index = pd.to_datetime(data_real.index) # omskriver til dato
data_real = data_real.resample('M').last() # de seneste måneder
data_real.index = data_real.index.strftime('%Y-%b') #dataformat

data_all = pd.concat([data_nom,data_real],axis=1) # samler data til et datasæt

# %% [markdown]
# # Q1

# %%
from matplotlib import dates as mdates 

plt.rcParams["figure.figsize"] = [15,6] 

data_nom.index =  pd.to_datetime(data_nom.index)
fig_nom = data_nom.plot(title='Nominal yields', ylabel='Pct.', xlabel='Year', x_compat=True) # Opstiller plot
fig_nom.xaxis.set_major_locator(mdates.YearLocator())
fig_nom = fig_nom.get_figure() # Indsætter data
fig_nom.savefig('01_nom.eps',format='eps') # Gemmer plot i fil

data_real.index = pd.to_datetime(data_real.index)
fig_real = data_real.plot(title='Real yields', ylabel='Pct.', xlabel='Year', x_compat=True) # Opstiller plot
fig_real.xaxis.set_major_locator(mdates.YearLocator())
fig_real = fig_real.get_figure() # Indsætter data
fig_real.savefig('01_real.eps',format='eps') # Gemmer plot i fil

plt.show() # Viser plots
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Q2

# %%
scaler = StandardScaler() # standardiserer funktioner ved at fjerne middelværdien og skalere til enhedsvarians (standardafvigelse)
nom_std = scaler.fit_transform(data_nom) # skalerer, fitter og transformerer data
real_std = scaler.fit_transform(data_real) #skalerer, fitter og transformerer data

pca_real = PCA(n_components=5) # PCA hvor vi beholder 5 komponenter
pca_nom = PCA(n_components=5) # PCA hvor vi beholder 5 komponenter

X_real = pca_real.fit_transform(real_std) # PCA, fitter, transformerer 'real'
X_nom = pca_nom.fit(nom_std) # PCA, fitter 'nominel' % Hvorfor ikke transform her? %


df = pd.DataFrame(
    {
        'EVar_Real': np.round(pca_real.explained_variance_ratio_,4)*100, # andel af varians forklaret af de valgte komponenter med 4 decimaler i procent
        'EVar_Nom': np.round(pca_nom.explained_variance_ratio_,4)*100, # andel af varians forklaret af de valgte komponenter med 4 decimaler i procent
        'Cum_EVar_Real': np.cumsum(np.round(pca_real.explained_variance_ratio_,4)*100), # akkkumulerede sum af ovenstående
        'Cum_EVar_Nom': np.cumsum(np.round(pca_nom.explained_variance_ratio_,4)*100) # akkkumulerede sum af ovenstående
    }, index=range(1,6)) # returnerer en række tal mellem 1 og 6
df.index.name = 'PCA Components' # Overskrift i tabel
print(df)
# Out:
#                 EVar_Real  EVar_Nom  Cum_EVar_Real  Cum_EVar_Nom
# PCA Components
# 1                   96.02     93.07          96.02         93.07
# 2                    3.76      6.77          99.78         99.84
# 3                    0.21      0.15          99.99         99.99
# 4                    0.01      0.00         100.00         99.99
# 5                    0.00      0.00         100.00         99.99

# %% [markdown]
# # Q3

# %%
# BEI rates for maturities of 2, 5, 10 years
data_bei = data_nom.join(data_real, on = 'Date') # Matcher datasæt ift. dato i en string

for x in ['02', '03', '05', '07', '10']:
    data_bei['BEI' + x] = data_bei['SVENY' + x] - data_bei['TIPSY' + x] # Henter data for 2, 5 og 10 årige med udgangspunkt i formel for BEI = Nominel - Real

data_bei = data_bei[['BEI02', 'BEI03', 'BEI05', 'BEI07', 'BEI10']] # Gemmer BEI som nyt datasæt

fig, ax = plt.subplots() # flere kurver i et plot
data_bei.plot(ax = ax)
ax.set_ylabel('Pct.') # label på y-aksen
ax.set_title('Break Even Interest Rate (BEI)') # titel
#fig.savefig('03_BEI.eps',format='eps') # Gemmer plot i fil
# Out:
# Text(0.5, 1.0, 'Break Even Interest Rate (BEI)')

# %% [markdown]
# # Q5

# %%
# Definerer alpha, beta, P og y med udgangspunkt i Q4
def alpha(tau, sigma_L=0.005, sigma_S=0.01, lambda_=0.5):
    return sigma_L**2*tau**3/6 + sigma_S**2/(2*lambda_**2) * (tau - (np.exp(-2*lambda_*tau)-1)/(2*lambda_) + (2*np.exp(-lambda_*tau)-2)/lambda_)

def beta(tau,lambda_=0.5):
    return np.array([-(tau),-1/lambda_ + np.exp(-lambda_*tau)/lambda_])

# Find ud af hvor udtryk for P og y kommer fra!!!
def P(tau, X): 
    if isinstance(tau, float) or isinstance(tau, int):
        return np.exp(alpha(tau)+beta(tau).T @ X) # bemærk @ er matrixprodukt (prik)        
    return np.exp(alpha(tau)+beta(tau).T @ X)[0]

def y(tau,X):
    return 0.0 if tau == 0 else -np.log(P(tau,X)) / (tau)

# %% [markdown]
# # Q11

# %% [markdown]
# #### Helper functions

# %%
"""
    LinAlg Helper functions used to calculate conditional and unconditional variance-matrices 
"""
# Definerer hjælpefunktioner som skal bruges til Kalman

def eigen_decomp(KP, verbose=0): 
    # Perform Eigen-decomposition of a matrix A = QDQ^-1,
    # where Q is a matrix with the eigenvectors of A and
    #       D is a diagonal matrix with the eigenvalues of A
    # Returns: Q, D, Q^-1
    eigenvalues, Q = np.linalg.eig(KP)
    if verbose >= 2:
        if any(eig < 0 for eig in eigenvalues):
            print("At least one of the eigenvalues are not (strictly) positive:")
            print(eigenvalues)
    D = np.diag(eigenvalues)
    return Q, D, np.linalg.inv(Q) # returnerer egenværdier Q (vektor), diagonalmatrix med egenværdier D og inverse egenværdier Q^-1

def calcmat_S(KP, Sigma, verbose=0):
    # Calculate S = Q^-1 S S^T (Q^-1)^T
    Q, D, Q_inv = eigen_decomp((KP), verbose)
    return Q_inv @ Sigma @ Sigma.T @ Q_inv.T


def calcmat_Vcond(KP, Sigma, tau, verbose=0):
    # Calculate V_ij = S_ij / (D_i + D_j) * (1- exp{-(D_i + D_j)*(T-t)})
    S = calcmat_S(KP, Sigma)
    Q, D, Q_inv = eigen_decomp((KP), verbose)
    V = np.zeros(np.shape(KP))

    N, M = np.shape(V)
    for i in range(N):
        for j in range(M):
            V[i, j] = S[i, j] / (D[i, i] + D[j, j]) * (1 - np.exp (-(D[i, i] + D[j, j]) * (tau)))
    return V


def calcmat_Vuncond(KP, Sigma, verbose=0):
    # Calculate V_ij = S_ij / (D_i + D_j)
    S = calcmat_S(KP, Sigma)
    Q, D, Q_inv = eigen_decomp((KP), verbose)
    V = np.zeros(np.shape(KP))

    N, M = np.shape(V)
    for i in range(N):
        for j in range(M):
            V[i, j] = S[i, j] / (D[i, i] + D[j, j])

    return V


def calcMat_condVar(KP, Sigma, tau, verbose=0):
    # Calculate uncondVar = Q V Q^T
    Q, D, Q_inv = eigen_decomp((KP), verbose)
    V = calcmat_Vcond(KP, Sigma, tau, verbose)
    return Q @ V @ Q.T


def calcMat_uncondVar(KP, Sigma, verbose=0):
    # Calculate uncondVar = Q V Q^T
    Q, D, Q_inv = eigen_decomp((KP), verbose)
    V = calcmat_Vuncond(KP, Sigma, verbose)
    return Q @ V @ Q.T

# %% [markdown]
# #### Infamous Kalman Class Ⓒ

# %%
class Kalmanfilter:
    """
    Class to initiate, estimate and evaluate a Kalman Filter on a dataset.
    Objective is to estimate the parameters of the state price variable, X(t), with P-dynamics
                dX(t) = K^P [thetaP - X(t)]dt + Sigma dW^P(t).
    Yields (both nominal and real) are denoted as y(t; tau), each of these curves have 5 tenors (tau).
    The class assumes eod of month data.
    """
    def __init__(self, df, KP, thetaP, tau_vec: np.array,
                 sigma_L_nom: float, sigma_L_real: float, sigma_S_nom: float, sigma_S_real: float,
                 lambda_nom: float, lambda_real: float, sigma_err: float, penalty: float = 1e6,
                 verbose=0):
        # Arguments
        self.df = df/100
        self.KP = KP
        self.thetaP = thetaP
        self.tau = tau_vec
        self.dt = 1 / 12

        self.sigma_L_nom = np.abs(sigma_L_nom)
        self.sigma_L_real = np.abs(sigma_L_real)
        self.sigma_S_nom = np.abs(sigma_S_nom)
        self.sigma_S_real = np.abs(sigma_S_real)
        self.penalty = penalty
        self.lambda_nom = lambda_nom
        self.lambda_real = lambda_real
        self.sigma_err = sigma_err**2
        self.verbose = verbose

        # Parameters
        self.SigmaP = np.diag([self.sigma_L_nom, self.sigma_S_nom, self.sigma_L_real, self.sigma_S_real])

        # Constants
        self.T, self.N = self.df.shape

        self.F = scipy.linalg.expm(-self.KP * self.dt)
        self.C = self.thetaP - self.F @ self.thetaP
        self.Q = np.real(calcMat_condVar(self.KP, self.SigmaP, self.dt, verbose=1))

        self.A = -np.concatenate([alpha(tau=self.tau, sigma_L=self.sigma_L_nom, sigma_S=self.sigma_S_nom, lambda_=self.lambda_nom) / self.tau,
                                  alpha(tau=self.tau, sigma_L=self.sigma_L_real, sigma_S=self.sigma_S_real, lambda_=self.lambda_real) / self.tau]).reshape(-1, 1)

        self.B = -np.block(
            [[beta(tau=self.tau, lambda_=self.lambda_nom).reshape(2, 5).T / self.tau[:, None], np.zeros([5, 2])],
             [np.zeros([5, 2]), beta(tau=self.tau, lambda_=self.lambda_real).reshape(2, 5).T / self.tau[:, None]]])
        self.H = self.sigma_err * np.eye(10)

        # Variables
        self.loglik = 0#float(self.N * self.T / 2 * np.log(2 * np.pi))

        self.Xlag = None
        self.Xt = thetaP  # Uncondition Mean
        self.Plag = None
        self.Pt = np.real(calcMat_uncondVar(self.KP, self.SigmaP, verbose=1))

        self.yt = None
        self.nut = None
        self.St = None
        self.Kt = None

        eigenvals = np.real(np.linalg.eig(self.KP)[0])

        if any(eig < 0 for eig in eigenvals):
            if self.verbose >= 3:
                print('KP has negative eigenvalues:')
                print(eigenvals)
            self.loglik += float(self.penalty)

    def predict_Xt(self):
        self.Xlag = np.real(self.F @ self.Xt + self.C)

    def predict_Pt(self):
        self.Plag = np.real(self.F @ self.Pt @ self.F.T + self.Q)

    def update_yt(self, t):
        self.yt = self.df.iloc[t, :].to_numpy().reshape(10, 1)

    def update_nut(self):
        self.nut = np.real(self.yt - self.A - self.B @ self.Xlag)

    def update_St(self):
        self.St = np.real(self.H + self.B @ self.Plag @ self.B.T)

    def update_Kt(self):
        self.Kt = np.real(self.Plag @ self.B.T @ np.linalg.inv(self.St))

    def update_Xt(self):
        self.Xt = np.real(self.Xlag + self.Kt @ self.nut)

    def update_Pt(self):
        self.Pt = np.real((np.eye(4) - self.Kt @ self.B) @ self.Plag)

    def update_loglik(self):
        det = np.linalg.det(self.St)
        if det <= 0:
            loglik_term = float(self.penalty)
        else:
            loglik_term = 1 / 2 * (np.log(det) + self.nut.T @ np.linalg.inv(self.St) @ self.nut)
        if (loglik_term < 0) and (self.verbose >= 3):
            print('Negative loglikelihood-term: \n\t log(det)={} \n\t other={}'.format(np.log(det), self.nut.T @ np.linalg.inv(self.St) @ self.nut))
        if np.iscomplex(loglik_term) and (self.verbose >= 2):
            print('Complex loglikelihoold-term: {}'.format(loglik_term))
        self.loglik += float(np.real(loglik_term))


    def fit_kalman(self):
        """ Method used to train/fit the kalman filter"""
        #self.yfit = np.empty((self.T, self.N))
        for row in range(self.T):

            # Predict step
            self.predict_Xt()
            self.predict_Pt()

            # Update step
            self.update_yt(t=row) 
            self.update_nut()
            self.update_St()
            self.update_Kt()
            self.update_Xt()
            self.update_Pt()
            self.update_loglik()

    def generate_attributes(self):
        """ Method used to generate and calculate attributes needed for evaluations on the final parameters """
        self.yfit = np.empty((self.T, self.N))
        self.xfit = np.empty((self.T + 1, 4))
        self.xfit[0, :] = self.Xt.reshape(1, 4)

        for row in range(self.T):

            # Predict step
            self.predict_Xt()
            self.predict_Pt()

            # Update step
            self.update_yt(t=row)
            self.update_nut()
            self.update_St()
            self.update_Kt()
            self.update_Xt()
            self.update_Pt()
            self.update_loglik()

            self.yfit[row, :] = (self.A + self.B @ self.Xt).reshape(1, 10)
            self.xfit[row + 1, :] = self.Xt.reshape(1, 4)


    def calc_RMSE(self):
        """ Method for calculating Root Mean Squared Error (RMSE) """
        y_obs = self.df
        y_fit = pd.DataFrame(self.yfit, columns=self.df.columns, index=self.df.index)

        self.mse = ((y_fit - y_obs)**2).mean(axis=0)
        self.rmse = np.sqrt(self.mse)

    # end of class

# %% [markdown]
# #### Optimizer functions

# %%
"""
    Preprocessing, helper-functions and objective funtion for fitting the kalman filter of the state price variable
"""
data_nom_real = data_nom.join(data_real)

df = data_nom_real

"""
KP = np.eye(4)                     # 16
thetaP = np.zeros((4,1))           # 4
tau_vec = np.array([2,3,5,7,10])   
sigma_L_nom=0.001                  # 1
sigma_L_real=0.001                 # 1
sigma_S_nom=0.05                   # 1
sigma_S_real=0.05                  # 1
lambda_nom = 1.0                   # 1
lambda_real = 1.0                  # 1
sigma_err = 0.01                   # 1
penalty = 1e6            

"""


def kalman_optim(x0, df, optim_func='loglik', verbose=0, penalty=1e6):
    # Format arguments
    KP = x0[:16].reshape([4, 4])
    thetaP = x0[16:20].reshape(4, 1)
    sigma_L_nom = np.abs(x0[20])
    sigma_L_real = np.abs(x0[21])
    sigma_S_nom = np.abs(x0[22])
    sigma_S_real = np.abs(x0[23])
    lambda_nom = x0[24]
    lambda_real = x0[25]
    sigma_err = x0[26]

    tau_vec = np.array([2, 3, 5, 7, 10])

    kalman = Kalmanfilter(df, KP, thetaP, tau_vec,
                          sigma_L_nom, sigma_L_real, sigma_S_nom, sigma_S_real,
                          lambda_nom, lambda_real, sigma_err, penalty, verbose)
    kalman.fit_kalman()
    loglik = kalman.loglik
    # rmse = np.max(kalman.rmse)

    if optim_func.lower() == 'loglik':
        z = loglik
    # elif optim_func.lower() == 'rmse':
    #    z = rmse

    if verbose >= 1:
        print(z)
    return z

# Tvinger funktionen til ikke at finde lokalt minimum
def repeated_optim(x0, N=5, max_iter=2500, max_fev=3000, func_tol=1.0, verbose=0, tol=5E-4, fatol=5E-4, xatol=5E-4, method='Nelder-Mead'):
    """
    Helper-function for running repeated optimization with the current most optimal value

    :param x0:          Initial parameters to be optimized
    :param N:           Number of iterations in rep.
    :param max_iter:    Maximum number of iterations in the optimization step
    :param max_fev:     Maximum number of function evaluations in the optimization step
    :param func_tol:    Required improvement of function value to start another rep.
    :param verbose:     Amount of information displayed
    :return:            <scipy.optimize.OptimizeResult>-object from the optimization
    """
    f_opt = 5000
    for i in range(N):
        dt_start = datetime.now()
        print('Starting', i, 'at time ', dt_start)
        optim = scipy.optimize.minimize(fun=kalman_optim,
                                        x0=x0,
                                        args=(df, 'loglik', verbose, 1e6),
                                        # Data, optimization method, verbose, penalty
                                        method=method,
                                        tol=tol,
                                        options={'maxiter': max_iter,  # Maximum iterations
                                                 'maxfev': max_fev,
                                                 # Maximum function evaluations (might be several per iter.)
                                                 'adaptive': True,  # Better for higher dimensional problems
                                                 'disp': True,  # Display message at termination
                                                 'xatol': xatol,  # Stops when |x_n - x_{n-1}| < xatol
                                                 'fatol': fatol}  # Stops when |f_n - f_{n-1}| < fatol
                                        )
        dt_end = datetime.now()
        print('Finished', i, 'at time', dt_end)
        print('Time of iteration:\t', dt_end - dt_start)
        print(i, ':\t', optim.fun)
        print('\n' * 3)

        # Use optimal value
        x0 = optim['x']

        # Stopping criteria
        if abs(f_opt - optim.fun) < func_tol:
            print('Insufficient improvement between iterations...')
            break
        else:
            f_opt = optim.fun

    return optim

# %% [markdown]
# #### Estimation

# %%
"""
    Train / fit kalman filter to estimate parameters of the state price variable
"""

# Initial parameter values

x0 = np.array([
  1.5,  0.7,  0.4,  0.5,
  1.0,   .7,  0.2,  0.7,
   .3,   .1,  1.1,  .9,
   -3.,  .5, -1.5,  2.5,        # KP, mean reversion
 
  0.06, 0.07, 0.01, 0.01,       #thetaP, det konstante niveau x bevæger sig rundt om
 
  0.01, 0.001, 0.001, 0.001,   #sigma

  0.5, 0.5,  0.01               #lambda, lambda, sigma_err
  ])

# Check if all eigen values are positive
x0_eig_vals = np.linalg.eig(np.array(x0[:16]).reshape(4, 4))[0]

if any(x0_eig_vals < 0):
    raise ValueError('Negative eigenvalues in initial parameters: \n{}'.format(x0_eig_vals))

# Start optimization
optim = repeated_optim(x0=x0, N=10, max_iter=10000, max_fev=15000, func_tol=2, verbose=0, method='Nelder-Mead')
# Out:
# Starting 0 at time  2023-05-03 08:52:20.384194
# Finished 0 at time 2023-05-03 09:41:38.202009
# Time of iteration:	 0:49:17.817815
# 0 :	 -12278.160338624031
#
#
#
#
# Starting 1 at time  2023-05-03 09:41:38.202009
# Optimization terminated successfully.
#          Current function value: -12479.257844
#          Iterations: 8854
#          Function evaluations: 14023
# Finished 1 at time 2023-05-03 10:06:18.532283
# Time of iteration:	 0:24:40.330274
# 1 :	 -12479.257844009033
#
#
#
#
# Starting 2 at time  2023-05-03 10:06:18.532283
# Optimization terminated successfully.
#          Current function value: -12479.988213
#          Iterations: 582
#          Function evaluations: 8182
# Finished 2 at time 2023-05-03 10:20:50.985296
# Time of iteration:	 0:14:32.453013
# 2 :	 -12479.988213148525
#
#
#
#
# Insufficient improvement between iterations...

# %% [markdown]
# #### Evaluation

# %%
"""
    Use optimized parameters and perform evaluation
"""
x0 = optim['x']

with open('x02023.pickle', 'wb') as handle:
    pickle.dump(x0, handle, protocol=pickle.HIGHEST_PROTOCOL)


# Format arguments
KP = x0[:16].reshape([4, 4])
thetaP = x0[16:20].reshape(4, 1)
sigma_L_nom = np.abs(x0[20])
sigma_L_real = np.abs(x0[21])
sigma_S_nom = np.abs(x0[22])
sigma_S_real = np.abs(x0[23])
lambda_nom = x0[24]
lambda_real = x0[25]
sigma_err = x0[26]

tau_vec = np.array([2, 3, 5, 7, 10])

kalman = Kalmanfilter(df, KP, thetaP, tau_vec,
                        sigma_L_nom, sigma_L_real, sigma_S_nom, sigma_S_real,
                        lambda_nom, lambda_real, sigma_err)

kalman.generate_attributes()
kalman.calc_RMSE()

X_opt = pd.DataFrame(kalman.xfit, columns=['level_nom', 'slope_nom', 'level_real', 'slope_real'])

kalman.yfit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Emilie Munkedal\OneDrive\Dokumenter\GitHub\Bachelor\notebook-1 resultater til martin.ipynb Cell 29 in 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> """
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a>     Use optimized parameters and perform evaluation
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> """
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X40sZmlsZQ%3D%3D?line=3'>4</a> x0 = optim['x']
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X40sZmlsZQ%3D%3D?line=5'>6</a> with open('x02023.pickle', 'wb') as handle:
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X40sZmlsZQ%3D%3D?line=6'>7</a>     pickle.dump(x0, handle, protocol=pickle.HIGHEST_PROTOCOL)
#
# NameError: name 'optim' is not defined

# %% [markdown]
# # Q12

# %%
X_opt.plot(title = 'Estimated state price variable').legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.tight_layout()
# plt.savefig('12_state_price.png', dpi=1200)
plt.savefig('12_state_price_2023.eps',format='eps')
plt.show()


print(np.round(x0[:16].reshape(4,4),6))
print(np.round(x0[16:20], 6))
print(np.round(x0[20:24], 6))
print(np.round(x0[24:], 6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Emilie Munkedal\OneDrive\Dokumenter\GitHub\Bachelor\notebook-1 resultater til martin.ipynb Cell 33 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> X_opt.plot(title = 'Estimated state price variable').legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> plt.tight_layout()
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> # plt.savefig('12_state_price.png', dpi=1200)
#
# NameError: name 'X_opt' is not defined

# %%
import pickle
import pandas as pd

# Load the data from the pickle file
with open('x02023.pickle', 'rb') as f:
    data = pickle.load(f)

# df = pd.DataFrame(data)
# df.to_csv(r'2022estimarer.csv')
# # Print the data
# print(data)

# %% [markdown]
# # Q13

# %%
print('\n'*3)
print('RMSE summary:')
print(kalman.rmse)
print('\n')
print('Loglikhihood = ', kalman.loglik)

# Plot fitted yields vs. observed yields
df_fit = pd.DataFrame(kalman.yfit)
df_fit.columns = df.columns + '_FIT'
df_fit.index = df.index


df_1 = df.iloc[:, [0,4]].join(df_fit.iloc[:, [0,4]]*100)
df_2 = df.iloc[:, [5,9]].join(df_fit.iloc[:, [5,9]]*100)


df_1.plot(color=['blue', 'fuchsia', 'red', 'lime'],
          alpha=1, title='Nominal', ylabel='Pct.').legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.tight_layout()
plt.savefig('13_nominal.eps',format='eps')

df_2.plot(color=['blue', 'fuchsia', 'red', 'lime'],
          alpha=1, title='Real', ylabel='Pct.').legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.tight_layout()
plt.savefig('13_real.eps',format='eps')
plt.show()

#['blue', 'lime', 'darkorange', 'fuchsia', 'chocolate', 'red', 'aqua', 'gold', 'pink', 'darkviolet']
# Out:
# RMSE summary:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Emilie Munkedal\OneDrive\Dokumenter\GitHub\Bachelor\notebook-1 resultater til martin.ipynb Cell 34 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> print('\n'*3)
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> print('RMSE summary:')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X46sZmlsZQ%3D%3D?line=2'>3</a> print(kalman.rmse)
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X46sZmlsZQ%3D%3D?line=3'>4</a> print('\n')
#       <a href='vscode-notebook-cell:/c%3A/Users/Emilie%20Munkedal/OneDrive/Dokumenter/GitHub/Bachelor/notebook-1%20resultater%20til%20martin.ipynb#X46sZmlsZQ%3D%3D?line=4'>5</a> print('Loglikhihood = ', kalman.loglik)
#
# AttributeError: 'Kalmanfilter' object has no attribute 'rmse'

# %% [markdown]
# ### Model implied BEI

# %%
# Plot observed yields - fitted yields 

with open('x02023.pickle', 'rb') as handle:
    x0 = pickle.load(handle)


# Format arguments
KP = x0[:16].reshape([4, 4])
thetaP = x0[16:20].reshape(4, 1)
sigma_L_nom = np.abs(x0[20])
sigma_L_real = np.abs(x0[21])
sigma_S_nom = np.abs(x0[22])
sigma_S_real = np.abs(x0[23])
lambda_nom = x0[24]
lambda_real = x0[25]
sigma_err = x0[26]


tau_vec = np.array([2, 3, 5, 7, 10])

kalman_estimate_woOptim = Kalmanfilter(df, KP, thetaP, tau_vec,
                        sigma_L_nom, sigma_L_real, sigma_S_nom, sigma_S_real,
                        lambda_nom, lambda_real, sigma_err)

kalman_estimate_woOptim.generate_attributes()
kalman_estimate_woOptim.calc_RMSE()

# Dataframe med fittede x'ere
df_fit = pd.DataFrame(kalman_estimate_woOptim.yfit)
df_fit.columns = df.columns + '_FIT'
df_fit.index = df.index


df_BEI_02 = df_fit.iloc[:, 0]*(100)-(df_fit.iloc[:, 5]*(100))
df_BEI_03 = df_fit.iloc[:, 1]*(100)-(df_fit.iloc[:, 6]*(100))
df_BEI_05 = df_fit.iloc[:, 2]*(100)-(df_fit.iloc[:, 7]*(100))
df_BEI_07 = df_fit.iloc[:, 3]*(100)-(df_fit.iloc[:, 8]*(100))
df_BEI_10 = df_fit.iloc[:, 4]*(100)-(df_fit.iloc[:, 9]*(100))

# Plot observed yields - fitted yields 
fig, ax = plt.subplots(figsize=(18, 8))

ax.plot(df_BEI_02.index, df_BEI_02.values, label='2 years')
#ax.plot(df_BEI_03.index, df_BEI_03.values, label='3 years')
#ax.plot(df_BEI_05.index, df_BEI_05.values, label='5 years')
#ax.plot(df_BEI_07.index, df_BEI_07.values, label='7 years')
ax.plot(df_BEI_10.index, df_BEI_10.values, label='10 years')

ax.axhline(y=0, color='black', linestyle='--')

ax.set_xlabel('Year')
ax.set_ylabel('Pct.')
ax.set_title('Model implied BEI')
ax.legend()

plt.show()
plt.savefig('model_BEI.eps',format='eps')


# Calculate model implied BEI
df_bei = pd.DataFrame(kalman_estimate_woOptim.yfit[:, :5] - kalman_estimate_woOptim.yfit[:, 5:],
                      columns=['BEI_' + x for x in ['02', '03', '05', '07', '10']], index=data_bei.index)

# %% [markdown]
# ## FED v Model BEI

# %%
data_bei = data_nom.join(data_real, on = 'Date') # Matcher datasæt ift. dato i en string

for x in ['02', '10']:
    data_bei['BEI' + x] = data_bei['SVENY' + x] - data_bei['TIPSY' + x] # Henter data for 2, 5 og 10 årige med udgangspunkt i formel for BEI = Nominel - Real

data_bei_02_10 = data_bei[['BEI02', 'BEI10']] # Gemmer BEI som nyt datasæt


df_BEI_02 = df_fit.iloc[:, 0]*(100)-(df_fit.iloc[:, 5]*(100))
df_BEI_10 = df_fit.iloc[:, 4]*(100)-(df_fit.iloc[:, 9]*(100))
# df_BEI_02_FED = df.iloc[:, 0]*-(df.iloc[:, 5])
# df_BEI_10_FED = df.iloc[:, 4]*-(df.iloc[:, 9])

# Plot observed yields - fitted yields 
fig, ax = plt.subplots(figsize=(18, 8))

ax.plot(df_BEI_02.index, df_BEI_02.values, label='Model BEI 2y', color='blue')
ax.plot(df_BEI_10.index, df_BEI_10.values, label='Model BEI 10y', color='fuchsia')
# ax.plot(df_BEI_02_FED.index, df_BEI_02_FED.values, label='FED BEI 2y')
# ax.plot(df_BEI_10_FED.index, df_BEI_10_FED.values, label='FED BEI 10y')
data_bei_02_10.plot(ax = ax, color=['red','lime'])


ax.axhline(y=0, color='black', linestyle='--')

ax.set_xlabel('Year')
ax.set_ylabel('Pct.')
ax.set_title('Model implied BEI v FED')
ax.legend()


plt.show()
plt.savefig('model_BEI_FEDvMODEL.eps',format='eps')

# %% [markdown]
# ### 2y and 10y v slope

# %%
X_opt_slope = X_opt.iloc[:, 1] #slope nominal

df_fit_02 = df_fit.iloc[:, 0]*(100) #2y nominal
df_fit_10 = df_fit.iloc[:, 4]*(100) #10y nominal

# Plot observed yields - fitted yields 
fig, ax = plt.subplots(figsize=(18, 8))

ax.plot(df_fit_02.index, df_fit_02.values, label='Fitted 2y nominal', color='blue')
ax.plot(df_fit_10.index, df_fit_10.values, label='Fitted 10y nominal', color='lime')
# ax.plot(df_BEI_02_FED.index, df_BEI_02_FED.values, label='FED BEI 2y')
# ax.plot(df_BEI_10_FED.index, df_BEI_10_FED.values, label='FED BEI 10y')
X_opt_slope.plot(ax = ax, color=['red'])

ax.axhline(y=0, color='black', linestyle='--')

ax.set_title('Fitted 2y and 10y nominal v slope')
ax.legend()

plt.show()
plt.savefig('2y_10y_slope.eps',format='eps')

# %% [markdown]
# ### 1y v level

# %%
# Read data (Skipping lines without data)
data_nom_01 = pd.read_csv("data_nom.csv", sep=",", skiprows=9) # indlæser fil

# Select maturities 1 year and end_of_month dates
data_nom_01 = data_nom.query("Date >= '2005-01-01' and Date <= '2023-03-31'").set_index('Date')
data_nom_01 = data_nom[['SVENY01']]

data_nom_01.index = pd.to_datetime(data_nom_01.index) # omskriver til dato
data_nom_01 = data_nom.resample('M').last() # de seneste måneder
data_nom_01.index = data_nom_01.index.strftime('%Y-%b') # dataformat

X_opt_level = X_opt.iloc[:, 0] #level nominal

# Plot observed yields - fitted yields 
fig, ax = plt.subplots(figsize=(18, 8))

ax.plot(data_nom_01.index, data_nom_01.values, label='1y nominal', color='lime')
# ax.plot(df_BEI_02_FED.index, df_BEI_02_FED.values, label='FED BEI 2y')
# ax.plot(df_BEI_10_FED.index, df_BEI_10_FED.values, label='FED BEI 10y')

X_opt_level.plot(ax = ax, color=['red'])

ax.axhline(y=0, color='black', linestyle='--')

ax.set_title('1y nominal v level')
ax.legend()

plt.show()
plt.savefig('1y_level.eps',format='eps')

# %% [markdown]
# ### Forskelle, reel

# %%
# Plot observed yields - fitted yields 
df_diff_02 = df.iloc[:, 5]-(df_fit.iloc[:, 5]*(100))
df_diff_03 = df.iloc[:, 6]-(df_fit.iloc[:, 6]*(100))
df_diff_05 = df.iloc[:, 7]-(df_fit.iloc[:, 7]*(100))
df_diff_07 = df.iloc[:, 8]-(df_fit.iloc[:, 8]*(100))
df_diff_10 = df.iloc[:, 9]-(df_fit.iloc[:, 9]*(100))

# Plot observed yields - fitted yields 
fig, ax = plt.subplots(figsize=(18, 8))

ax.plot(df_diff_02.index, df_diff_02.values, label='2 years')
ax.plot(df_diff_03.index, df_diff_03.values, label='3 years')
ax.plot(df_diff_05.index, df_diff_05.values, label='5 years')
ax.plot(df_diff_07.index, df_diff_07.values, label='7 years')
ax.plot(df_diff_10.index, df_diff_10.values, label='10 years')

ax.axhline(y=0, color='black', linestyle='--')

ax.set_xlabel('Year')
ax.set_ylabel('Difference (%)')
ax.set_title('Difference between observed and fitted real yields')
ax.legend()

plt.show()
plt.savefig('diff_real.eps',format='eps')

# %% [markdown]
# ### Differences in observed and fitted yields, nominal

# %%
# Plot observed yields - fitted yields 
df_diff_02 = df.iloc[:, 0]-(df_fit.iloc[:, 0]*(100))
df_diff_03 = df.iloc[:, 1]-(df_fit.iloc[:, 1]*(100))
df_diff_05 = df.iloc[:, 2]-(df_fit.iloc[:, 2]*(100))
df_diff_07 = df.iloc[:, 3]-(df_fit.iloc[:, 3]*(100))
df_diff_10 = df.iloc[:, 4]-(df_fit.iloc[:, 4]*(100))

# Plot observed yields - fitted yields 
fig, ax = plt.subplots(figsize=(18, 8))

ax.plot(df_diff_02.index, df_diff_02.values, label='2 years')
ax.plot(df_diff_03.index, df_diff_03.values, label='3 years')
ax.plot(df_diff_05.index, df_diff_05.values, label='5 years')
ax.plot(df_diff_07.index, df_diff_07.values, label='7 years')
ax.plot(df_diff_10.index, df_diff_10.values, label='10 years')

ax.axhline(y=0, color='black', linestyle='--')

ax.set_xlabel('Year')
ax.set_ylabel('Difference (%)')
ax.set_title('Difference between observed and fitted nominal yields')
ax.legend()

plt.show()
plt.savefig('diff_nominal.eps',format='eps')

# %% [markdown]
# # Q15

# %%
# x0 = np.array([ 1.308003, 0.091473, -0.544941,  0.505512,
#         1.744948, 0.583144, -0.876675,  0.957497,
#         0.4508, 0.219821, -1.07043,   0.54152, 
#         -0.20631, 0.580202, -4.122645,  1.292813,
#         0.035259, -0.040453,  0.008985, -0.01528,
#         0.006729, 0.006425, 0.003192, 0.001742,
#         0.177165, 0.383123, 0.001263])

with open('x02023.pickle', 'rb') as handle:
    x0 = pickle.load(handle)    


        
# Format arguments
KP = x0[:16].reshape([4, 4])
thetaP = x0[16:20].reshape(4, 1)
sigma_L_nom = np.abs(x0[20])
sigma_L_real = np.abs(x0[21])
sigma_S_nom = np.abs(x0[22])
sigma_S_real = np.abs(x0[23])
lambda_nom = x0[24]
lambda_real = x0[25]
sigma_err = x0[26]
tau_vec = np.array([2, 3, 5, 7, 10])


kalman = Kalmanfilter(df, KP, thetaP, tau_vec,
                        sigma_L_nom, sigma_L_real, sigma_S_nom, sigma_S_real,
                        lambda_nom, lambda_real, sigma_err)

kalman.generate_attributes()
X_opt = pd.DataFrame(kalman.xfit[1:, :].T)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def funcAlpha(KP,thetaP,Sigma,Beta):
    return (np.dot(np.dot(thetaP.T,KP.T), Beta) + 0.5 * np.dot(Beta.T,np.dot(Sigma,np.dot(Sigma.T,Beta))))[0][0]

def funcBeta(KP, Beta):
    return -np.array([1, 1, -1, -1]).reshape(-1,1) - np.dot(KP.T, Beta)

def calcPi(tau,A,B,X):
    return 1/(-tau) *  np.log((np.exp(A + B.T @ X)))

Sigma = np.diag([sigma_L_nom, sigma_S_nom, sigma_L_real, sigma_S_real])

df_pi = pd.DataFrame(index=range(219))


for count, tau in enumerate([2,3,5,7,10]):
    B = np.array([0,0,0,0]).reshape(-1,1)
    A = 0
    h = 0.01
    iterations = int(tau/h)

    for i in range(iterations):

        k1B = h * funcBeta(KP,B)
        k1A = h * funcAlpha(KP,thetaP,Sigma,B)

        k2B = h * funcBeta(KP,B+0.5*k1B)
        k2A = h * funcAlpha(KP,thetaP,Sigma,B+0.5*k1B)

        k3B = h * funcBeta(KP,B+0.5*k2B)
        k3A = h * funcAlpha(KP,thetaP,Sigma,B+0.5*k2B)

        k4B = h * funcBeta(KP,B+k3B)
        k4A = h * funcAlpha(KP,thetaP,Sigma,B+k3B)

        B = B + (1.0/6.0)*(k1B+2.0*k2B + 2.0*k3B + k4B)
        A = A + (1.0/6.0)*(k1A+2.0*k2A + 2.0*k3A + k4A)


    df_pi[tau] = calcPi(tau, A, B, X_opt).T


df_pi.index = data_bei.index

# Expected inflation
fig, ax = plt.subplots(1)
df_pi.drop(columns=[3,7]).plot(title='Inflation Expectations', ylabel='Pct.', ax=ax).legend(title='Maturity')
ax.axhline(y=0, xmin=0, xmax=219, color='black', linestyle='--')
plt.savefig('12_ExpectedInflation.eps',format='eps')
plt.show()


# # Calculate model implied BEI
# df_bei = pd.DataFrame(kalman.yfit[:, :5] - kalman.yfit[:, 5:],
#                       columns=['BEI_' + x for x in ['02', '03', '05', '07', '10']], index=data_bei.index)

# # Expected inflation
# fig, ax = plt.subplots(1)
# df_bei.drop(columns=[3,7]).plot(title='Model implied BEI', ylabel='Pct.', ax=ax).legend(title='Maturity')
# ax.axhline(y=0, xmin=0, xmax=219, color='black', linestyle='--')
# plt.savefig('model_BEI.eps',format='eps')
# plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Q16

# %%
# Inflation risk premium
df_irp = pd.DataFrame(index=data_bei.index)

df_irp['IRP_02'] = df_bei['BEI_02'] - df_pi[2]
df_irp['IRP_05'] = df_bei['BEI_05'] - df_pi[5]
df_irp['IRP_10'] = df_bei['BEI_10'] - df_pi[10]


fig, ax = plt.subplots(1)
df_irp.plot(title='Inflation Risk Premium', ylabel='Pct.', ax=ax).legend(title='Maturity')
ax.axhline(y=0, xmin=0, xmax=219, color='black', linestyle='--')
plt.savefig('13_InflationsRisk.eps',format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import pickle

# Load the data from the pickle file
with open('x02023_fra2023mappe.pickle', 'rb') as f:
    data = pickle.load(f)

# Print the data
print(data)
# Out:
# [-1.56122749e-01 -3.40706117e-01  3.22839075e-01 -6.49225717e-02
#   6.88904796e-01  9.03259071e-01 -2.04048102e-01  1.29691470e-01
#  -8.84077468e-02 -1.54074073e-02  1.01836345e+00  2.70100300e-01
#   1.96629918e-01  2.41815206e-04 -1.51597113e+00 -3.92152289e-01
#   7.21978385e-02 -6.60061837e-02  1.86731696e-02  6.23860846e-05
#   7.86705135e-03  6.30152061e-03  4.59520157e-03  3.99599138e-03
#   1.29576342e-01  1.64197108e-01  8.37225003e-04]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7a50a976-9f0c-4bbf-b229-6a6bee440451' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
